# %%
from get_airports import get_airport_popular_times, load_airports
import numpy as np
import matplotlib.pyplot as plt
import itertools
# %matplotlib notebook

# %%
times = (get_airport_popular_times(airport) for airport in load_airports())
times = (time for time in times if time)
popular_times = [{time["name"]: time["data"] for time in day} for day in times]

days = list(popular_times[0].keys())

print(len(min((time[days[-1]] for time in popular_times), key=len)))
# Out:
# 24

# %%
print(days)
times = np.array([np.array(list(itertools.chain(*[airport[day] if airport[day] else [0]*24 for day in days]))) for airport in popular_times]).mean(axis=0)
plt.bar(range(len(times)), times)
# plt.xticks(range(len(times)), days)
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
# ([<matplotlib.axis.XTick at 0x111eda438>,
#   <matplotlib.axis.XTick at 0x111ec1f98>,
#   <matplotlib.axis.XTick at 0x111ed2048>,
#   <matplotlib.axis.XTick at 0x111a3bd30>,
#   <matplotlib.axis.XTick at 0x11200e550>,
#   <matplotlib.axis.XTick at 0x11200eba8>,
#   <matplotlib.axis.XTick at 0x11201b278>,
#   <matplotlib.axis.XTick at 0x11201b908>,
#   <matplotlib.axis.XTick at 0x11201bf98>,
#   <matplotlib.axis.XTick at 0x112021668>,
#   <matplotlib.axis.XTick at 0x112021cf8>,
#   <matplotlib.axis.XTick at 0x1120273c8>,
#   <matplotlib.axis.XTick at 0x112027a58>,
#   <matplotlib.axis.XTick at 0x11202d128>,
#   <matplotlib.axis.XTick at 0x11202d7b8>,
#   <matplotlib.axis.XTick at 0x11202de48>,
#   <matplotlib.axis.XTick at 0x112032518>,
#   <matplotlib.axis.XTick at 0x112032ba8>,
#   <matplotlib.axis.XTick at 0x112036278>,
#   <matplotlib.axis.XTick at 0x112036908>,
#   <matplotlib.axis.XTick at 0x112036f98>,
#   <matplotlib.axis.XTick at 0x11203b668>,
#   <matplotlib.axis.XTick at 0x11203bcf8>,
#   <matplotlib.axis.XTick at 0x1120413c8>,
#   <matplotlib.axis.XTick at 0x112041a58>,
#   <matplotlib.axis.XTick at 0x112047128>,
#   <matplotlib.axis.XTick at 0x1120477b8>,
#   <matplotlib.axis.XTick at 0x112047e48>,
#   <matplotlib.axis.XTick at 0x11204d518>,
#   <matplotlib.axis.XTick at 0x11204dba8>,
#   <matplotlib.axis.XTick at 0x112052278>,
#   <matplotlib.axis.XTick at 0x112052908>,
#   <matplotlib.axis.XTick at 0x112052f98>,
#   <matplotlib.axis.XTick at 0x112058668>,
#   <matplotlib.axis.XTick at 0x112058cf8>,
#   <matplotlib.axis.XTick at 0x1120603c8>,
#   <matplotlib.axis.XTick at 0x112060a58>,
#   <matplotlib.axis.XTick at 0x112068128>,
#   <matplotlib.axis.XTick at 0x1120687b8>,
#   <matplotlib.axis.XTick at 0x112068e48>,
#   <matplotlib.axis.XTick at 0x11206d518>,
#   <matplotlib.axis.XTick at 0x11206dba8>,
#   <matplotlib.axis.XTick at 0x112073278>,
#   <matplotlib.axis.XTick at 0x112073908>,
#   <matplotlib.axis.XTick at 0x112073f98>,
#   <matplotlib.axis.XTick at 0x112078668>,
#   <matplotlib.axis.XTick at 0x112078cf8>,
#   <matplotlib.axis.XTick at 0x11207f3c8>,
#   <matplotlib.axis.XTick at 0x11207fa58>,
#   <matplotlib.axis.XTick at 0x112086128>,
#   <matplotlib.axis.XTick at 0x1120867b8>,
#   <matplotlib.axis.XTick at 0x112086e48>,
#   <matplotlib.axis.XTick at 0x11208c518>,
#   <matplotlib.axis.XTick at 0x11208cba8>,
#   <matplotlib.axis.XTick at 0x112093278>,
#   <matplotlib.axis.XTick at 0x112093908>,
#   <matplotlib.axis.XTick at 0x112093f98>,
#   <matplotlib.axis.XTick at 0x112099668>,
#   <matplotlib.axis.XTick at 0x112099cf8>,
#   <matplotlib.axis.XTick at 0x1120a03c8>,
#   <matplotlib.axis.XTick at 0x1120a0a58>,
#   <matplotlib.axis.XTick at 0x1120a7128>,
#   <matplotlib.axis.XTick at 0x1120a77b8>,
#   <matplotlib.axis.XTick at 0x1120a7e48>,
#   <matplotlib.axis.XTick at 0x1120ad518>,
#   <matplotlib.axis.XTick at 0x1120adba8>,
#   <matplotlib.axis.XTick at 0x1120b4278>,
#   <matplotlib.axis.XTick at 0x1120b4908>,
#   <matplotlib.axis.XTick at 0x1120b4f98>,
#   <matplotlib.axis.XTick at 0x1120bb668>,
#   <matplotlib.axis.XTick at 0x1120bbcf8>,
#   <matplotlib.axis.XTick at 0x1120c03c8>,
#   <matplotlib.axis.XTick at 0x1120c0a58>,
#   <matplotlib.axis.XTick at 0x1120c6128>,
#   <matplotlib.axis.XTick at 0x1120c67b8>,
#   <matplotlib.axis.XTick at 0x1120c6e48>,
#   <matplotlib.axis.XTick at 0x1120ce518>,
#   <matplotlib.axis.XTick at 0x1120ceba8>,
#   <matplotlib.axis.XTick at 0x1120d4278>,
#   <matplotlib.axis.XTick at 0x1120d4908>,
#   <matplotlib.axis.XTick at 0x1120d4f98>,
#   <matplotlib.axis.XTick at 0x1120db668>,
#   <matplotlib.axis.XTick at 0x1120dbcf8>,
#   <matplotlib.axis.XTick at 0x1120e03c8>,
#   <matplotlib.axis.XTick at 0x1120e0a58>,
#   <matplotlib.axis.XTick at 0x1120e7128>,
#   <matplotlib.axis.XTick at 0x1120e77b8>,
#   <matplotlib.axis.XTick at 0x1120e7e48>,
#   <matplotlib.axis.XTick at 0x1120ed518>,
#   <matplotlib.axis.XTick at 0x1120edba8>,
#   <matplotlib.axis.XTick at 0x1120f5278>,
#   <matplotlib.axis.XTick at 0x1120f5908>,
#   <matplotlib.axis.XTick at 0x1120f5f98>,
#   <matplotlib.axis.XTick at 0x1120fb668>,
#   <matplotlib.axis.XTick at 0x1120fbcf8>,
#   <matplotlib.axis.XTick at 0x1121013c8>,
#   <matplotlib.axis.XTick at 0x112101a58>,
#   <matplotlib.axis.XTick at 0x112107128>,
#   <matplotlib.axis.XTick at 0x1121077b8>,
#   <matplotlib.axis.XTick at 0x112107e48>,
#   <matplotlib.axis.XTick at 0x11210c518>,
#   <matplotlib.axis.XTick at 0x11210cba8>,
#   <matplotlib.axis.XTick at 0x112114278>,
#   <matplotlib.axis.XTick at 0x112114908>,
#   <matplotlib.axis.XTick at 0x112114f98>,
#   <matplotlib.axis.XTick at 0x11211b668>,
#   <matplotlib.axis.XTick at 0x11211bcf8>,
#   <matplotlib.axis.XTick at 0x1121233c8>,
#   <matplotlib.axis.XTick at 0x112123a58>,
#   <matplotlib.axis.XTick at 0x112128128>,
#   <matplotlib.axis.XTick at 0x1121287b8>,
#   <matplotlib.axis.XTick at 0x112128e48>,
#   <matplotlib.axis.XTick at 0x11212e518>,
#   <matplotlib.axis.XTick at 0x11212eba8>,
#   <matplotlib.axis.XTick at 0x112135278>,
#   <matplotlib.axis.XTick at 0x112135908>,
#   <matplotlib.axis.XTick at 0x112135f98>,
#   <matplotlib.axis.XTick at 0x11213b668>,
#   <matplotlib.axis.XTick at 0x11213bcf8>,
#   <matplotlib.axis.XTick at 0x1121423c8>,
#   <matplotlib.axis.XTick at 0x112142a58>,
#   <matplotlib.axis.XTick at 0x11214a128>,
#   <matplotlib.axis.XTick at 0x11214a7b8>,
#   <matplotlib.axis.XTick at 0x11214ae48>,
#   <matplotlib.axis.XTick at 0x11214e518>,
#   <matplotlib.axis.XTick at 0x11214eba8>,
#   <matplotlib.axis.XTick at 0x112155278>,
#   <matplotlib.axis.XTick at 0x112155908>,
#   <matplotlib.axis.XTick at 0x112155f98>,
#   <matplotlib.axis.XTick at 0x11215b668>,
#   <matplotlib.axis.XTick at 0x11215bcf8>,
#   <matplotlib.axis.XTick at 0x1121623c8>,
#   <matplotlib.axis.XTick at 0x112162a58>,
#   <matplotlib.axis.XTick at 0x112169128>,
#   <matplotlib.axis.XTick at 0x1121697b8>,
#   <matplotlib.axis.XTick at 0x112169e48>,
#   <matplotlib.axis.XTick at 0x11216e518>,
#   <matplotlib.axis.XTick at 0x11216eba8>,
#   <matplotlib.axis.XTick at 0x112176278>,
#   <matplotlib.axis.XTick at 0x112176908>,
#   <matplotlib.axis.XTick at 0x112176f98>,
#   <matplotlib.axis.XTick at 0x11217d668>,
#   <matplotlib.axis.XTick at 0x11217dcf8>,
#   <matplotlib.axis.XTick at 0x1121833c8>,
#   <matplotlib.axis.XTick at 0x112183a58>,
#   <matplotlib.axis.XTick at 0x11218a128>,
#   <matplotlib.axis.XTick at 0x11218a7b8>,
#   <matplotlib.axis.XTick at 0x11218ae48>,
#   <matplotlib.axis.XTick at 0x11218e518>,
#   <matplotlib.axis.XTick at 0x11218eba8>,
#   <matplotlib.axis.XTick at 0x112195278>,
#   <matplotlib.axis.XTick at 0x112195908>,
#   <matplotlib.axis.XTick at 0x112195f98>,
#   <matplotlib.axis.XTick at 0x11219d668>,
#   <matplotlib.axis.XTick at 0x11219dcf8>,
#   <matplotlib.axis.XTick at 0x1121a43c8>,
#   <matplotlib.axis.XTick at 0x1121a4a58>,
#   <matplotlib.axis.XTick at 0x1121aa128>,
#   <matplotlib.axis.XTick at 0x1121aa7b8>,
#   <matplotlib.axis.XTick at 0x1121aae48>,
#   <matplotlib.axis.XTick at 0x1121b0518>,
#   <matplotlib.axis.XTick at 0x1121b0ba8>,
#   <matplotlib.axis.XTick at 0x1121b5278>,
#   <matplotlib.axis.XTick at 0x1121b5908>,
#   <matplotlib.axis.XTick at 0x1121b5f98>,
#   <matplotlib.axis.XTick at 0x1121bb668>,
#   <matplotlib.axis.XTick at 0x1121bbcf8>,
#   <matplotlib.axis.XTick at 0x1121c23c8>],
#  <a list of 7 Text xticklabel objects>)
